# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
#View dataset
# max1, min1: pair plots of highest and lowest prices
HousePrice = pd.read_csv("house_price.csv", delimiter = ',', header = 0)
print(HousePrice, '\n')
max1 = max(HousePrice['price'])
min1 = min(HousePrice['price'])
max2 = max(HousePrice['area'])
min2 = min(HousePrice['area'])
max3 = max(HousePrice['rooms'])
min3 = min(HousePrice['rooms'])
# Out:
#     area  rooms   price
# 0   2104      3  399900
# 1   1600      3  329900
# 2   2400      3  369000
# 3   1416      2  232000
# 4   3000      4  539900
# 5   1985      4  299900
# 6   1534      3  314900
# 7   1427      3  198999
# 8   1380      3  212000
# 9   1494      3  242500
# 10  1940      4  239999
# 11  2000      3  347000
# 12  1890      3  329999
# 13  4478      5  699900
# 14  1268      3  259900
# 15  2300      4  449900
# 16  1320      2  299900
# 17  1236      3  199900
# 18  2609      4  499998
# 19  3031      4  599000
# 20  1767      3  252900
# 21  1888      2  255000
# 22  1604      3  242900
# 23  1962      4  259900
# 24  3890      3  573900
# 25  1100      3  249900
# 26  1458      3  464500
# 27  2526      3  469000
# 28  2200      3  475000
# 29  2637      3  299900
# 30  1839      2  349900
# 31  1000      1  169900
# 32  2040      4  314900
# 33  3137      3  579900
# 34  1811      4  285900
# 35  1437      3  249900
# 36  1239      3  229900
# 37  2132      4  345000
# 38  4215      4  549000
# 39  2162      4  287000
# 40  1664      2  368500
# 41  2238      3  329900
# 42  2567      4  314000
# 43  1200      3  299000
# 44   852      2  179900
# 45  1852      4  299900
# 46  1203      3  239500

# %% [markdown]
# # Single Regression

# %% [markdown]
# ## Least Squares Method

# %%
#Apply Single linear regression to detect outliers 
#Yield 2 formulae, detect outliers for area/price and for rooms/price
# Y = b01 + b1x1
# Y = b02 + b2x2
# Y: predicted dependent variable: price
# ymean: mean of dependent variable
# b01, b02: intercept of dependent variable: ymean - (b1*x1mean), ymean - (b2*x2mean)
# b1, b2: gradient of independent variables: area, rooms
# x1, x2: variables substituted, x1mean, x2mean of area and rooms
size = len(HousePrice['area'])
x1 = HousePrice['area']
x2 = HousePrice['rooms']
y = HousePrice['price']
x1mean = sum(HousePrice['area'])/size 
x2mean = sum(HousePrice['rooms'])/size
ymean = sum(HousePrice['price'])/size

print("size of data: ", size)
print("X1 MEAN: ", x1mean)
print("X2 MEAN: ", x2mean)
print("Y MEAN: ", ymean)
# Out:
# size of data:  47
# X1 MEAN:  2000.6808510638298
# X2 MEAN:  3.1702127659574466
# Y MEAN:  340412.6595744681

# %%
#First formula
# xx1total, xx2total: Sum of squared of area, rooms
# xy1total, xy2total: Sum of area*price, rooms*price
# slope1, slope2: equivalent to b1, b2
xx1total = 0
xy1total = 0
for i in range(size):
    x1diff = (x1[i] - x1mean)**2
    #print("x:", x1diff)
    xx1total = xx1total + x1diff
    y1diff = (x1[i] - x1mean) * (y[i] - ymean)
    #print("y:", ydiff)
    xy1total = xy1total + y1diff

#Sumxx = np.sum(xdiff, axis = 0, keepdims = True)
#Sumxy = np.sum(ydiff, axis = 0, keepdims = True)
print("SSx1: ", "{0: .3f}".format(xx1total), '\n')
print("SPxy1: ", "{0: .3f}".format(xy1total), '\n')

slope1 = xy1total / xx1total
print("Slope1 : ", "{0: .3f}".format(slope1), '\n')
intercept = ymean - (slope1 * x1mean)
print("Intercept: ", intercept, '\n')
print("y = ", slope1,"x1 + ", intercept, '\n')
# Out:
# SSx1:   29051384.213
#
# SPxy1:   3908145819.894
#
# Slope1 :   134.525
#
# Intercept:  71270.49244872906
#
# y =  134.52528772024135 x1 +  71270.49244872906

# %%
#Find predicted values and residuals
#Plot to find outliers, repeat for second formula then compare output with multiregression 
# predicted1, predicted2: calculate predicted values
# residual1, residual2: predicted1, predicted2 - actual  
predicted1 = []
residual1 = []

for p in range(size):
    #predicted = slope * (x1[p]) + intercept
    predicted1.append((slope1 * x1[p]) + intercept)
    residual1.append(predicted1[p] - y[p])
    #print("x1, area:", x1[p]," price, y:", y[p], "predicted price:", "{0: .2f}".format(predicted1[p]), 
          #"residual:", "{0: .2f}".format(residual1[p]))

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
import numpy as np
from numpy import ndarray
from numpy.linalg import eig

# %%
#fig, ax = plt.subplots(2, 2, figsize=(10,7))

figure, axis = plt.subplots(1, 2,  figsize=(10,5))
plt.rcParams.update({'font.size': 10})
figure.tight_layout()
#plt.figure(1, 1, figsize=(5, 5))
axis[0].scatter(x1, y, color = "blue", alpha = 1, s = 10)
axis[0].plot(x1, predicted1, color = "green", alpha = 0.2)
plt.xlabel("Area")
#plt.ylabel("Price")
axis[1].scatter(x1, residual1,  color = "blue", alpha = 1, s = 20)
axis[1].plot(x1, residual1,  color = "cyan", alpha = 0.2)
plt.legend(["residual"], loc ="upper right")
plt.grid()
#axis[1].margins(x = 0, y = 0)
#plt.xlim(0, 5)
#plt.ylim(0, 100)
#plt.xlabel("Area")
#plt.ylabel("Residual")
plt.grid()
plt.axis('equal')
plt.show()
standardisedresidual1 = residual1 / np.std(residual1)
print(standardisedresidual1)
# Out:
# [-0.71056159 -0.67628293  0.39170692  0.46382743 -1.01395795  0.5985709
#  -0.58087287  1.00126172  0.70007325  0.46371789  1.43786224 -0.10410111
#  -0.06976067 -0.40875988 -0.28135862 -1.07891778 -0.7957858   0.58673388
#  -1.21186564 -1.87011939  0.87403852  1.09501691  0.68812877  1.17380461
#   0.32223293 -0.47775226 -3.07196675 -0.90274813 -1.67981636  1.96566949
#  -0.48688302  0.5594892   0.48009629 -1.35015908  0.45194255  0.22886158
#   0.12542953  0.20384644  1.39178904  1.17076614 -1.1437277   0.66146079
#   1.5991256  -1.0333712   0.09330131  0.31969956 -0.09968474]

# %%
#Plot standard residuals of Multiregression model
plt.figure(figsize=(3, 3))
#axmulti = fig.add_subplot(projection='2d')
plt.scatter(x1,standardisedresidual1, color = 'blue')
plt.show()

# %%
#Second Formula
xx2total = 0
xy2total = 0
for j in range(size):
    x2diff = (x2[i] - x2mean)**2
    #print("x:", x2diff)
    xx2total = xx2total + x2diff
    y2diff = (x2[i] - x2mean) * (y[i] - ymean)
    #print("y:", y2diff)
    xy2total = xy2total + y2diff

#Sumxx2 = np.sum(xdiff2, axis = 0, keepdims = True)
#Sumxy2 = np.sum(ydiff2, axis = 0, keepdims = True)
print("SSx2: ", "{0: .3f}".format(xx2total), '\n')
print("SPxy2: ", "{0: .3f}".format(xy2total), '\n')

slope2 = xy2total / xx2total
print("Slope2 : ", "{0: .3f}".format(slope2), '\n')
intercept2 = ymean - (slope2 * x2mean)
print("Intercept: ", intercept2, '\n')
print("y = ", slope2,"x2 + ", intercept2, '\n')
# Out:
# SSx2:   1.362
#
# SPxy2:   807301.277
#
# Slope2 :   592861.875
#
# Intercept:  -1539085.6250000047
#
# y =  592861.8750000015 x2 +  -1539085.6250000047

# %%
predicted2 = []
residual2 = []

for q in range(size):
    #predicted2 = slope * (x2[q]) + intercept
    predicted2.append((slope2 * x2[q]) + intercept2)
    residual2.append(predicted2[q] - y[q])
    #print("x2, rooms:", x2[q]," price, y:", y[q], "predicted price:", "{0: .2f}".format(predicted2[q]), 
          #"residual:", "{0: .2f}".format(residual2[q]))

# %%
figure2, axis2 = plt.subplots(1, 2,  figsize=(10,5))
figure2.tight_layout()
plt.rcParams.update({'font.size': 10})
#plt.figure(1, 1, figsize=(5, 5))
axis2[0].scatter(x2, y, color = "red", alpha = 1, s = 10)
axis2[0].plot(x2, predicted2, color = "orange", alpha = 0.5)
plt.xlabel("Rooms")
plt.grid()

#plt.ylabel("Price")
axis2[1].scatter(x2, residual2,  color = "red", alpha = 1, s = 20)
axis2[1].plot(x2, residual2,  color = "yellow", alpha = 0.2)
plt.legend(["residual"], loc ="upper right")
plt.grid()
#axis[1].margins(x = 0, y = 0)
#plt.xlim(0, 5)
#plt.ylim(0, 100)
#plt.xlabel("Area")
#plt.ylabel("Residual")
plt.axis('equal')
plt.show()
standardisedresidual2 = residual2 / np.std(residual2)
print(standardisedresidual2)
# Out:
# [-0.39406892 -0.2220937  -0.31815414 -1.43811047  0.71851705  1.30814635
#  -0.18524187  0.0995024   0.06756169 -0.00737037  1.45531045 -0.26410479
#  -0.22233693  1.78196723 -0.05011849  0.93962803 -1.60492643  0.09728883
#   0.81654783  0.57332083 -0.03292097 -1.49461661 -0.00835308  1.4064179
#  -0.82155016 -0.0255506  -0.55277747 -0.56383302 -0.57857375 -0.14839004
#  -1.72776587 -2.74208028  1.27129452 -0.83629089  1.34254139 -0.0255506
#   0.02358517  1.19734517  0.69616027  1.33983892 -1.77346214 -0.2220937
#   1.27350563 -0.14617893 -1.31011178  1.30814635  0.        ]

# %%
#Plot standard residuals of Multiregression model
plt.figure(figsize=(3, 3))
#axmulti = fig.add_subplot(projection='2d')
plt.scatter(x2,standardisedresidual1, color = 'red')
plt.show()

# %% [markdown]
# ##### For example, words such as young, tall, good, or high are fuzzy. There is no single quantitative value which defines the term young when describing a fuzzy concept (or fuzzy variable) such as age. For some people, age 25 is young, and for others, age 35 is young. The concept young has no clean boundary.

# %% [markdown]
# # Multiple Regression

# %% [markdown]
# ## Using Least Squares Formula

# %% [raw]
# #Apply linear regression to detect outliers
# # Y = b0 + b1x1 + b2x2
# # Y: predicted dependent variable: PRICE
# # b0: intercept of dependent variable: Y - (b1*x1mean) - (b2*x2mean)
# # b1: gradient of independent variable: area
# # b2: gradient of independent variable: rooms
# x1 = HousePrice['area']
# x2 = HousePrice['rooms']
# y = HousePrice['price']
# size = len(HousePrice['area'])
# print("size of data: ", size)
# x1mean = sum(HousePrice['area'])/size
# x2mean = sum(HousePrice['rooms'])/size
# ymean = sum(HousePrice['price'])/size
# print("X1 MEAN: ", x1mean)
# print("X2 MEAN: ", x2mean)
# print("Y MEAN: ", ymean)

# %% [raw]
# xx1total = 0
# xy1total = 0
# xx2total = 0
# xy2total = 0
# for i in range(size):
#     x1diff = (x1[i] - x1mean)**2
#     #print("x:", x1diff)
#     x2diff = (x2[i] - x2mean)**2
#     xx1total = xx1total + x1diff
#     xx2total = xx2total + x2diff
#     y1diff = (x1[i] - x1mean) * (y[i] - ymean)
#     y2diff = (x2[i] - x2mean) * (y[i] - ymean)
#     #print("y:", ydiff)
#     xy1total = xy1total + y1diff
#     xy2total = xy2total + y2diff
#
# #Sumxx = np.sum(xdiff, axis = 0, keepdims = True)
# #Sumxy = np.sum(ydiff, axis = 0, keepdims = True)
# print("SSx1: ", "{0: .3f}".format(xx1total), '\n')
# print("SPxy1: ", "{0: .3f}".format(xy1total), '\n')
# print("SSx2: ", "{0: .3f}".format(xx2total), '\n')
# print("SPxy2: ", "{0: .3f}".format(xy2total), '\n')

# %%
#Equation will be in the form z = ax + by + c

slope1 = xy1total / xx1total
slope2 = xy2total / xx2total
print("Slope1 : ", "{0: .3f}".format(slope1), '\n')
print("Slope2 : ", "{0: .3f}".format(slope2), '\n')
intercept3 = ymean - (slope1 * x1mean) - (slope2 * x2mean)
print("Intercept: ", intercept3, '\n')
print("y = ", slope1,"x1 + ", slope2,"x2 + " ,intercept3, '\n')
# Out:
# Slope1 :   134.525
#
# Slope2 :   592861.875
#
# Intercept:  -1808227.7921257438
#
# y =  134.52528772024135 x1 +  592861.8750000015 x2 +  -1808227.7921257438

# %%
predicted3 = []
residual3 = []
#residual = predicted - actual
for r in range(size):
    #predicted = slope * (x[p]) + intercept
    predicted3.append((slope1 * x1[r])+(slope2 * x2[r])+ intercept3)
    residual3.append(predicted3[r] - y[r])
    #print("area:", x1[r], " rooms:", x2[r]," y:", y[r], "predicted:", "{0: .2f}".format(predicted3[r]), 
          #"residual:", "{0: .2f}".format(residual3[r]))

standardisedresidual3 = residual3 / np.std(residual3)
#print(standardisedresidual3)
#residual = predicted[p] - y[p]
#residual.append(predicted - y[p])

# %%
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs
import numpy as np
from numpy import ndarray
from numpy.linalg import eig
from mpl_toolkits import mplot3d
import warnings  
from sklearn import linear_model   
import seaborn as sns   
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
#Types of data visualisation
#Use pair plots
figs = sns.pairplot(HousePrice, height = 3.75)
figs.tight_layout()

# %%
#Plot entire dataset
# xxx, yyy, zzz: 2 independent variables and 1 dependent variable
# Multi: list of predicted values of multiregression equation
# fig, axes: used to initialise diagram
# axis1, axis2, axis3: subplots added in 3d, 1 row 3 columns, values of indices 1 2 3

zzz = HousePrice['price']
xxx = HousePrice['area']
yyy = HousePrice['rooms']

plt.style.use('fivethirtyeight')  
fig = plt.figure(figsize = (15, 6))
#axes = plt.axes(projection ="3d")
axis1 = fig.add_subplot(131, projection = '3d')  
axis2 = fig.add_subplot(132, projection = '3d')  
axis3 = fig.add_subplot(133, projection = '3d')  
axes = [axis1, axis2, axis3]  

for ax in axes:  
    #ax.plot(xxx, yyy, predicted3, color="black",zorder = 10, linestyle = 'none', marker = 'o', alpha = 0.1)
    #ax.plot(xxx, yyy, residual3, color='orange', zorder = 10, linestyle = 'none', marker = 'o', alpha = 0.1)  
    ax.scatter3D(xxx, yyy, zzz, color = "red", alpha = 1, s = 15)
    #ax.set_xlabel('Area', fontsize = 14, labelpad = 10)  
    #ax.set_ylabel('Rooms', fontsize = 14, labelpad = 15)  
  

axis1.view_init(elev=30, azim=-60)  
axis2.view_init(elev=20, azim=20)  
axis3.view_init(elev=30, azim=60)  
plt.legend(["actual data"], loc ="upper right")

# %%
# xxx1, yyy1: variables in multiregression equation: y = b1x1 + b2x2 + b0 (area, rooms respectively)
#Full details of plotting: 
#actual data: red
#predicted by regression equation: blue
#required data: black
f = plt.figure(figsize = (10, 7))
a = plt.axes(projection ="3d")
plt.rcParams.update({'font.size': 10})

xxx1 = [2567, 1200, 852, 1852, 1203] 
yyy1 = [5, 2, 5, 2, 3]
Multi = []
for m in range(len(xxx1)):
    Multi.append((slope1*xxx1[m]) + (slope2*yyy1[m]) + intercept3)
    print("Multiregression values of price:", Multi[m])
    Multi[m] = abs(Multi[m])
    
a.scatter3D(xxx, yyy, zzz, color = "red", alpha = 0.2, s = 20)
a.scatter3D(xxx, yyy, predicted3, color = "grey", alpha = 0.4)
a.scatter3D(xxx1, yyy1, Multi, color = "black", alpha = 1, s = 15)
plt.title("Scatter plot of entire dataset")
plt.legend(["actual data", "predicted", "required"], loc ="upper right")
plt.show()
# Out:
# Multiregression values of price: 1501407.996452123
# Multiregression values of price: -461073.69686145126
# Multiregression values of price: 1270697.1280119093
# Multiregression values of price: -373363.20926785376
# Multiregression values of price: 132191.75400171126

# %% [markdown]
# ## Using Python linear_model Construction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
from sklearn.linear_model import LinearRegression

# %%
#Predict using multiregression
X = HousePrice.iloc[:, :-1].values
#Y = HousePrice.iloc[:, :0].values
Z = HousePrice.iloc[:, 2].values #price Z

# %%
# Building the Multiple Linear Regression Model based on both independent and dependent variables   
# Printing the intercept and the coefficients of the regression equation  
MultiReg = linear_model.LinearRegression()
MultiReg.fit(X, Z)
# Out:
# LinearRegression()

# %%
print('Intercept: ', MultiReg.intercept_)  
print('Coefficients array: ', MultiReg.coef_)
R2 = MultiReg.score(X, Z)
print("R2 score:", R2)
# Out:
# Intercept:  89597.90954279748
# Coefficients array:  [  139.21067402 -8738.01911233]
# R2 score: 0.7329450180289141

# %%
# X1, X2: splitting of independent variables 
# New: new predicted prices that will be scattered as points after regression plane is found
X1 = X[:,0]
X2 = X[:,1]

New = []
New.append(MultiReg.predict([[2567, 5]]))
New.append(MultiReg.predict([[1200, 2]]))
New.append(MultiReg.predict([[852, 5]]))
New.append(MultiReg.predict([[1852, 2]]))
New.append(MultiReg.predict([[1203, 3]]))

#print(New, '\n')

predictedreg = MultiReg.predict(X)
residualreg = list(np.subtract(Z, predictedreg))
standardisedresidual4 = residualreg / np.std(residualreg)
print(standardisedresidual4)
#print("area:", x1[r], " rooms:", x2[r]," y:", y[r], "predicted:", "{0: .2f}".format(predicted3[r]), 
        #"residual:", "{0: .2f}".format(residual3[r]))

RegFig = plt.figure(figsize = (10,7))
RegAx = RegFig.add_subplot(projection ='3d')

RegAx.scatter3D(xxx, yyy, zzz, color = "red", alpha = 1, s = 15)
#Evenly spaced range of values start at min, stop at max and number of values is 40
XPredict = np.linspace(min(X1), max(X1), num = 40)
#print(X1Predict)

YPredict = np.linspace(min(X2), max(X2), num = 40)
xpredict, ypredict = np.meshgrid(XPredict, YPredict)

View = np.array([xpredict.flatten(), ypredict.flatten()]).T
#print(View)

predicted4 = MultiReg.predict(View)
#print(predicted4)

RegAx.scatter(xpredict.flatten(), ypredict.flatten(), predicted4, facecolor=(0,0,0,0), s=10, edgecolor='lightblue')
RegAx.scatter(X1, X2, predictedreg, color = "orange", alpha = 1, s = 5)
RegAx.scatter(xxx1, yyy1, New, color = "black", alpha = 1, s = 20 )
plt.title("Scatter plot of entire dataset")
plt.legend(["actual data", "predicted", "predicted on plane", "required"], loc ="upper right")
RegAx.set_xlabel('Area',  labelpad = 10)
RegAx.set_ylabel('Rooms',  labelpad = 10)
RegAx.set_zlabel('Price',  labelpad = 10)

plt.show()
# Out:
# [ 0.68230059  0.68483757 -0.44566181 -0.58261215  1.05781567 -0.48617026
#   0.59391875 -0.9861133  -0.68038733 -0.45152997 -1.32520828  0.08126244
#   0.05485972  0.47878309  0.312814    1.17431674  0.68860707 -0.55608249
#   1.28509919  1.91481111 -0.88334839 -1.25068616 -0.6848173  -1.06180512
#  -0.48514334  0.52223348  3.09962049  0.84425444  1.64803557 -2.04270522
#   0.3405442  -0.78481996 -0.37129698  1.24850614 -0.32625686 -0.21164388
#  -0.09332444 -0.10078793 -1.44571103 -1.07341437  1.01259826 -0.70452076
#  -1.53301183  1.0725388  -0.16940416 -0.19653913  0.13524511]

# %%
#Plot standard residuals of Multiregression model
plt.figure(figsize=(3, 3))
#axmulti = fig.add_subplot(projection='2d')
plt.scatter(X1,standardisedresidual4, color = 'grey')
plt.show()

# %%
#Plot standard residuals of Multiregression model
plt.figure(figsize=(3, 3))
#axmulti = fig.add_subplot(projection='2d')
plt.scatter(X2,standardisedresidual4, color = 'orange')
plt.show()
